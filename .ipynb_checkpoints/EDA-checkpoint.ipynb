# %%
import csv, os ; from glob import glob
import numpy as np ; import pandas as pd
import warnings
warnings.filterwarnings('ignore')

import import_ipynb
import MAZI_EDA
import utils

df_98,df_35,train_test_set,validation_set=MAZI.make_dataframe('GNB/100_new', 'GNB/35_new')
# Out:
# importing Jupyter notebook from MAZI.ipynb
# importing Jupyter notebook from utils.ipynb

# %%
df_98
# Out:
#         uid  Index  A_730_0  A_730_1  A_730_2  A_730_3  A_730_4  A_730_5  \
# 0         1      1     54.0     27.0     44.0     29.0     44.0     42.0
# 1         1      2     80.0     75.0    131.0     86.0     74.0    104.0
# 2         1      3     79.0     73.0    124.0     86.0     93.0     97.0
# 3         1      4     80.0     80.0    126.0     82.0     84.0     98.0
# 4         1      5     74.0     76.0    128.0     81.0     74.0    104.0
# ...     ...    ...      ...      ...      ...      ...      ...      ...
# 337216   99   3437     36.0     42.0     78.0     59.0     26.0     62.0
# 337217   99   3438     40.0     50.0     78.0     53.0     35.0     41.0
# 337218   99   3439     28.0     46.0     65.0     46.0     27.0     65.0
# 337219   99   3440     35.0     52.0     80.0     57.0     33.0     49.0
# 337220   99   3441     27.0     48.0     66.0     52.0     35.0     63.0
#
#         A_730_6  A_850_0  A_850_1  A_850_2  A_850_3  A_850_4  A_850_5  \
# ...

# %%
MAZI.raw_data_plot(df_98,98,14,4)
# Out:
# 특정 유저 특징 채널 불러오기

# %%
MAZI.data_boxplot(df_98)

# %%
MAZI.category_boxplot(df_98)

# %%
MAZI.columns_heatmap(df_98)

# %%
MAZI.scatter_per_category(df_98, 730)

# %%
MAZI.outlier_iqr(df_98, 'A_730_0',91)
# Out:
# IQR은 74.0 이다.
# lower bound 값은 -57.0 이다.
# upper bound 값은 239.0 이다.
# A_730_0 컬럼의 총 이상치 건수는 43051 이다.
# A_730_0 컬럼에 대한 모든 유저의 이상치를 출력합니다.
# 이상치가 존재하는 유저 목록 : [5, 9, 11, 19, 21, 22, 23, 30, 33, 37, 42, 44, 49, 50, 53, 55, 57, 58, 59, 60, 64, 67, 70, 72, 75, 79, 80, 81, 89, 90, 95]
# 91번 유저의 이상치 구간(실선은 제외) | 이상치 건수 : 0 (주황색 그래프)
# A_730_0 컬럼의 91 유저의 이상치를 출력합니다.

# %%
wave_98_N, wave_35_N = MAZI.wavelet_convert(df_98, df_35)
# Out:
# ...
#   0%|          | 0/38 [00:00<?, ?it/s]

# %%
MAZI.wavelet_plot(wave_98_N, 98, 14, 4)

# %%
# 광학밀도 변환
# start -> 신호는 측정시작시 각종 요소에 의해 많은 노이즈가 발생함
# 이를 제거하여 초기 구간의 불안정한 신호를 제거하여 광학밀도 변환을 실시합니다.
# 웨이블릿 변환한 데이터가 필요함

od_wave98, od_wave35 = MAZI.od_convert(wave_98_N, wave_35_N, 300)
# Out:
# ...
#   0%|          | 0/38 [00:00<?, ?it/s]

# %%
MAZI.od_plot(od_wave98, 98, 14, 4)

# %%
hb_98, hb_35 = MAZI.hc_convert(od_wave98, od_wave35)

# %%
MAZI.hb_plot(hb_98, 98, 14, 4)

# %%
chb_98, chb_35 = MAZI.chb_convert(hb_98, hb_35)

# %%
MAZI.chb_plot(chb_98, 98, 14, 4)
